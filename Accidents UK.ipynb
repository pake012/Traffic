# %%
#Import corresponding libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Import dataset 1
acc = pd.read_csv('2017 UK Accidents.csv')

# %%
acc.head
# Out:
# <bound method DataFrame.head of     Year  Killed Serious Injury Kiled and Serious Slight Injury All Severities
# 0   2002     304         3,229             3,533        15,742         19,275
# 1   2003     336         2,957             3,293        15,463         18,756
# 2   2004     308         2,766             3,074        15,428         18,502
# 3   2005     286         2,666             2,952        14,933         17,885
# 4   2006     314         2,635             2,949        14,320         17,269
# 5   2007     281         2,385             2,666        13,573         16,239
# 6   2008     270         2,575             2,845        12,747         15,592
# 7   2009     216         2,287             2,503        12,540         15,043
# 8   2010     208         1,969             2,177        11,161         13,338
# 9   2011     185         1,880             2,065        10,721         12,786
# 10  2012     176         1,981             2,157        10,555         12,712
# ...

# %%
acc.drop(6)
# Out:
#     Year  Killed Serious Injury Kiled and Serious Slight Injury  \
# 0   2002     304         3,229              3,533       15,742
# 1   2003     336         2,957              3,293       15,463
# 2   2004     308         2,766              3,074       15,428
# 3   2005     286         2,666              2,952       14,933
# 4   2006     314         2,635              2,949       14,320
# 5   2007     281         2,385              2,666       13,573
# 7   2009     216         2,287              2,503       12,540
# 8   2010     208         1,969              2,177       11,161
# 9   2011     185         1,880              2,065       10,721
# 10  2012     176         1,981              2,157       10,555
# 11  2013     172         1,669              1,841        9,654
# 12  2014     203         1,702              1,905        9,401
# 13  2015     168         1,601              1,769        9,204
# 14  2016     191         1,699              1,890        9,015
# ...

# %%
sns.countplot(x='Year',data=acc)
